# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips[0].keys()
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    return list(map(lambda trip:{'pickup_latitude': trip ['pickup_latitude'],'pickup_longitude': trip ['pickup_longitude'],'trip_distance':trip ['trip_distance']},trips))

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997',
#  'trip_distance': '18.379999999999999'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):
    return trips and list(map(lambda trip:{'pickup_latitude': float(trip ['pickup_latitude']),'pickup_longitude': float(trip ['pickup_longitude']),'trip_distance':float(trip ['trip_distance'])},trips))

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips[0]

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    return [trip['pickup_latitude'],trip['pickup_longitude']]

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    return folium.CircleMarker(location,radius=6)

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])
times_square_marker and times_square_marker.location


times_square_marker and json.loads(str(times_square_marker.options['radius'])) # 6# [40.7589, -73.9851]
# Out:
# 6

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(trips):
    locations=list(map(lambda trip:location(trip),trips))
    return list(map(lambda location:to_marker(location),locations))

# %%
trip_markers = markers_from_trips(cleaned_trips)

# %%
cleaned_trips[0:4]
# Out:
# [{'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'trip_distance': 18.38},
#  {'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'trip_distance': 4.5},
#  {'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'trip_distance': 2.4}]

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location,zoom_amount):
    return folium.Map(location=location,zoom_start=zoom_amount)

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
times_square_map and times_square_map.location # [40.7589, -73.9851]
# Out:
# [40.7589, -73.9851]

# %%
times_square_map and times_square_map.zoom_start # 15
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-23-26cf448630e7> in <module>
# ----> 1 times_square_map and times_square_map.zoom_start # 15
#
# AttributeError: 'Map' object has no attribute 'zoom_start'

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)

# %%
def add_markers(markers, map_obj):
    for marker in markers:
        marker.add_to(map_obj)

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)

# %%
map_with_markers

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
    distance_locations=(neighbor_trip['pickup_latitude']-selected_trip['pickup_latitude'])**2+(neighbor_trip['pickup_longitude']-selected_trip['pickup_longitude'])**2
    return math.sqrt(distance_locations)

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235
# Out:
# 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    neighbor_with_distance=neighbor_trip.copy()
    neighbor_with_distance['distance_from_selected']=distance_location(selected_trip, neighbor_trip)
    return neighbor_with_distance

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}
# Out:
# {'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3,
#  'distance_from_selected': 0.23505256047318146}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    remaining_neighbor=filter(lambda neighbor:neighbor!=selected_individual,neighbors)
    return list(map(lambda neighbor:distance_between_neighbors(selected_individual, neighbor),remaining_neighbor))

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [{'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'trip_distance': 1.3,
#   'distance_from_selected': 0.23505256047318146},
#  {'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'trip_distance': 4.5,
#   'distance_from_selected': 0.2162779533470808},
#  {'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'trip_distance': 2.4,
#   'distance_from_selected': 0.24242215976473674}]

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    neighbor_distance=distance_all(selected_trip, trips)
    sorted_neighbor=sorted(neighbor_distance,key=lambda trip :trip['trip_distance'])
    return sorted_neighbor[:number]

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]
# Out:
# [{'pickup_latitude': 40.80726,
#   'pickup_longitude': -73.954179,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.23721422331091302},
#  {'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.2339651232064361},
#  {'pickup_latitude': 40.732893,
#   'pickup_longitude': -73.974918,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.2127744703506549}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip
# Out:
# 2.822

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]
# Out:
# [{'pickup_latitude': 40.80726,
#   'pickup_longitude': -73.954179,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.05377430669938969},
#  {'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.002067074502774709},
#  {'pickup_latitude': 40.732893,
#   'pickup_longitude': -73.974918,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.029864970333153797},
#  {'pickup_latitude': 40.690387,
#   'pickup_longitude': -74.177668,
#   'trip_distance': 0.0,
#   'distance_from_selected': 0.20754782290594906},
#  {'pickup_latitude': 40.751087,
#   'pickup_longitude': -73.9716,
#   'trip_distance': 0.06,
#   'distance_from_selected': 0.015407586735116519},
#  {'pickup_latitude': 40.725012,
#   'pickup_longitude': -73.995492,
#   'trip_distance': 0.06,
#   'distance_from_selected': 0.03884388018723263},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 0.1,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.742682,
#   'pickup_longitude': -73.972513,
#   'trip_distance': 0.12,
#   'distance_from_selected': 0.021611704999832813},
#  {'pickup_latitude': 40.7951,
#   'pickup_longitude': -73.97166,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.03518667503473136},
#  {'pickup_latitude': 40.787171,
#   'pickup_longitude': -73.953967,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.03843565232957033},
#  {'pickup_latitude': 40.767867,
#   'pickup_longitude': -73.963893,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.019846217221426068},
#  {'pickup_latitude': 40.773736,
#   'pickup_longitude': -73.959905,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.025825872705479643},
#  {'pickup_latitude': 40.758902,
#   'pickup_longitude': -73.979668,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.00417676046715393},
#  {'pickup_latitude': 40.755123,
#   'pickup_longitude': -73.97283,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.01191610124998882},
#  {'pickup_latitude': 40.787654,
#   'pickup_longitude': -73.952104,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.040160695611502165},
#  {'pickup_latitude': 40.777596,
#   'pickup_longitude': -73.98351,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.01590369441356483},
#  {'pickup_latitude': 40.766251,
#   'pickup_longitude': -73.98011,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.005257678289889865},
#  {'pickup_latitude': 40.733294,
#   'pickup_longitude': -74.002744,
#   'trip_distance': 0.2,
#   'distance_from_selected': 0.03473944893057918},
#  {'pickup_latitude': 40.77958,
#   'pickup_longitude': -73.957862,
#   'trip_distance': 0.25,
#   'distance_from_selected': 0.030647141856945403},
#  {'pickup_latitude': 40.761363,
#   'pickup_longitude': -73.969672,
#   'trip_distance': 0.25,
#   'distance_from_selected': 0.01309259916899236},
#  {'pickup_latitude': 40.738437,
#   'pickup_longitude': -73.999686,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.02877710904521303},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 0.3,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.79858,
#   'pickup_longitude': -73.969018,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.03934767418793455},
#  {'pickup_latitude': 40.793391,
#   'pickup_longitude': -73.967215,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.035289272959357326},
#  {'pickup_latitude': 40.775985,
#   'pickup_longitude': -73.947142,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.03837209336223268},
#  {'pickup_latitude': 40.749559,
#   'pickup_longitude': -73.975903,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.013952248922665606},
#  {'pickup_latitude': 40.753714,
#   'pickup_longitude': -73.992042,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.012251185248781302},
#  {'pickup_latitude': 40.751752,
#   'pickup_longitude': -73.990012,
#   'trip_distance': 0.3,
#   'distance_from_selected': 0.01231881763806345},
#  {'pickup_latitude': 40.741115,
#   'pickup_longitude': -74.00577,
#   'trip_distance': 0.31,
#   'distance_from_selected': 0.030880643208974354},
#  {'pickup_latitude': 40.765657,
#   'pickup_longitude': -73.970445,
#   'trip_distance': 0.34,
#   'distance_from_selected': 0.012932054515814447},
#  {'pickup_latitude': 40.75284,
#   'pickup_longitude': -73.989232,
#   'trip_distance': 0.35,
#   'distance_from_selected': 0.010980149543610939},
#  {'pickup_latitude': 40.770792,
#   'pickup_longitude': -73.961915,
#   'trip_distance': 0.37,
#   'distance_from_selected': 0.02273756251227796},
#  {'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.022290517378471243},
#  {'pickup_latitude': 40.752144,
#   'pickup_longitude': -73.977199,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.011064948124595634},
#  {'pickup_latitude': 40.769822,
#   'pickup_longitude': -73.960596,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.023601852469670937},
#  {'pickup_latitude': 40.751607,
#   'pickup_longitude': -73.993449,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.01470800224367681},
#  {'pickup_latitude': 40.723516,
#   'pickup_longitude': -73.985065,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.03826348992186101},
#  {'pickup_latitude': 40.74277,
#   'pickup_longitude': -73.984523,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.019021876064153412},
#  {'pickup_latitude': 40.774935,
#   'pickup_longitude': -73.963839,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.02308473231380831},
#  {'pickup_latitude': 40.764972,
#   'pickup_longitude': -73.977855,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.005890642494663438},
#  {'pickup_latitude': 40.767759,
#   'pickup_longitude': -73.989694,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.009201671424256723},
#  {'pickup_latitude': 40.791595,
#   'pickup_longitude': -73.968651,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.03304810291075942},
#  {'pickup_latitude': 40.763835,
#   'pickup_longitude': -73.915012,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.06778131843656676},
#  {'pickup_latitude': 40.785612,
#   'pickup_longitude': -73.951147,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.039631898427902},
#  {'pickup_latitude': 40.774841,
#   'pickup_longitude': -73.963199,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.02355962397832097},
#  {'pickup_latitude': 40.781736,
#   'pickup_longitude': -73.981283,
#   'trip_distance': 0.4,
#   'distance_from_selected': 0.020080393546941258},
#  {'pickup_latitude': 40.778537,
#   'pickup_longitude': -73.981967,
#   'trip_distance': 0.41,
#   'distance_from_selected': 0.01684567535007064},
#  {'pickup_latitude': 40.756415,
#   'pickup_longitude': -73.975227,
#   'trip_distance': 0.42,
#   'distance_from_selected': 0.009207774649716786},
#  {'pickup_latitude': 40.75375,
#   'pickup_longitude': -73.99242,
#   'trip_distance': 0.42,
#   'distance_from_selected': 0.012517076335950113},
#  {'pickup_latitude': 40.745647,
#   'pickup_longitude': -73.978275,
#   'trip_distance': 0.43,
#   'distance_from_selected': 0.016677385706402134},
#  {'pickup_latitude': 40.765242,
#   'pickup_longitude': -73.960702,
#   'trip_distance': 0.43,
#   'distance_from_selected': 0.022338988070189168},
#  {'pickup_latitude': 40.745007,
#   'pickup_longitude': -73.998627,
#   'trip_distance': 0.44,
#   'distance_from_selected': 0.023038053259769844},
#  {'pickup_latitude': 40.73832,
#   'pickup_longitude': -73.9918,
#   'trip_distance': 0.45,
#   'distance_from_selected': 0.02507615799918198},
#  {'pickup_latitude': 40.769387,
#   'pickup_longitude': -73.953623,
#   'trip_distance': 0.45,
#   'distance_from_selected': 0.030131397212879964},
#  {'pickup_latitude': 40.800642,
#   'pickup_longitude': -73.967692,
#   'trip_distance': 0.46,
#   'distance_from_selected': 0.041746200401954994},
#  {'pickup_latitude': 40.73111,
#   'pickup_longitude': -74.00658,
#   'trip_distance': 0.47,
#   'distance_from_selected': 0.038778246479179705},
#  {'pickup_latitude': 40.737012,
#   'pickup_longitude': -73.99704,
#   'trip_distance': 0.47,
#   'distance_from_selected': 0.028529101002310278},
#  {'pickup_latitude': 40.74964,
#   'pickup_longitude': -73.972212,
#   'trip_distance': 0.48,
#   'distance_from_selected': 0.016029510410490794},
#  {'pickup_latitude': 40.744697,
#   'pickup_longitude': -73.98626,
#   'trip_distance': 0.49,
#   'distance_from_selected': 0.017369288097097427},
#  {'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.04120579237194523},
#  {'pickup_latitude': 40.790712,
#   'pickup_longitude': -73.972809,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.030661676487105636},
#  {'pickup_latitude': 40.793682,
#   'pickup_longitude': -73.966972,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.03565767418101985},
#  {'pickup_latitude': 40.793261,
#   'pickup_longitude': -73.940565,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.052686655103540043},
#  {'pickup_latitude': 40.74886,
#   'pickup_longitude': -73.988666,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.014142253568648767},
#  {'pickup_latitude': 40.764774,
#   'pickup_longitude': -73.992049,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.009781289127713548},
#  {'pickup_latitude': 40.777513,
#   'pickup_longitude': -73.948801,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.0374559539993265},
#  {'pickup_latitude': 40.753302,
#   'pickup_longitude': -73.979382,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.009061200141263505},
#  {'pickup_latitude': 40.763197,
#   'pickup_longitude': -73.989376,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.00678104896014711},
#  {'pickup_latitude': 40.754248,
#   'pickup_longitude': -73.972058,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.013046618259148537},
#  {'pickup_latitude': 40.760643,
#   'pickup_longitude': -73.962616,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.02017223896844562},
#  {'pickup_latitude': 40.77919,
#   'pickup_longitude': -73.954987,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.03281600111225863},
#  {'pickup_latitude': 40.769372,
#   'pickup_longitude': -73.984837,
#   'trip_distance': 0.5,
#   'distance_from_selected': 0.007938524611030853},
#  {'pickup_latitude': 40.77338,
#   'pickup_longitude': -73.954888,
#   'trip_distance': 0.53,
#   'distance_from_selected': 0.030216506813332534},
#  {'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'trip_distance': 0.53,
#   'distance_from_selected': 0.02597364710624614},
#  {'pickup_latitude': 40.743667,
#   'pickup_longitude': -73.983815,
#   'trip_distance': 0.54,
#   'distance_from_selected': 0.018073817361032782},
#  {'pickup_latitude': 40.764807,
#   'pickup_longitude': -73.97669,
#   'trip_distance': 0.55,
#   'distance_from_selected': 0.006814419197547772},
#  {'pickup_latitude': 40.75261,
#   'pickup_longitude': -73.978503,
#   'trip_distance': 0.55,
#   'distance_from_selected': 0.010046494363708589},
#  {'pickup_latitude': 40.74772,
#   'pickup_longitude': -73.98274,
#   'trip_distance': 0.56,
#   'distance_from_selected': 0.01399001429591807},
#  {'pickup_latitude': 40.749027,
#   'pickup_longitude': -73.98395,
#   'trip_distance': 0.57,
#   'distance_from_selected': 0.012738704368971492},
#  {'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'trip_distance': 0.58,
#   'distance_from_selected': 0.00037310588309379025},
#  {'pickup_latitude': 40.755637,
#   'pickup_longitude': -73.96482,
#   'trip_distance': 0.58,
#   'distance_from_selected': 0.01894003508444108},
#  {'pickup_latitude': 40.7446,
#   'pickup_longitude': -73.985232,
#   'trip_distance': 0.59,
#   'distance_from_selected': 0.01728765119963002},
#  {'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.017316422176655244},
#  {'pickup_latitude': 40.775933,
#   'pickup_longitude': -73.962446,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.02479823229587133},
#  {'pickup_latitude': 40.73925,
#   'pickup_longitude': -74.000759,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.02878220980050388},
#  {'pickup_latitude': 40.743385,
#   'pickup_longitude': -73.981978,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.018341677922150447},
#  {'pickup_latitude': 40.763685,
#   'pickup_longitude': -73.977714,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.005418739798139023},
#  {'pickup_latitude': 40.76305,
#   'pickup_longitude': -73.969831,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.012998255306001294},
#  {'pickup_latitude': 40.715884,
#   'pickup_longitude': -73.959979,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.051176129562517665},
#  {'pickup_latitude': 40.750445,
#   'pickup_longitude': -73.98674,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.011947410807368481},
#  {'pickup_latitude': 40.761912,
#   'pickup_longitude': -73.975275,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.007487725221990988},
#  {'pickup_latitude': 40.821517,
#   'pickup_longitude': -73.954177,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.06628623641450596},
#  {'pickup_latitude': 40.794009,
#   'pickup_longitude': -73.966721,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.036062098136407254},
#  {'pickup_latitude': 40.746631,
#   'pickup_longitude': -73.9819,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.015103504262256725},
#  {'pickup_latitude': 40.760955,
#   'pickup_longitude': -73.969252,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.01352908308053584},
#  {'pickup_latitude': 40.751248,
#   'pickup_longitude': -73.994112,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.015437660055854776},
#  {'pickup_latitude': 40.745711,
#   'pickup_longitude': -74.008496,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.03030362514617287},
#  {'pickup_latitude': 40.671487,
#   'pickup_longitude': -73.984354,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.09023707976768919},
#  {'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.039794696857747815},
#  {'pickup_latitude': 40.742366,
#   'pickup_longitude': -73.99317,
#   'trip_distance': 0.6,
#   'distance_from_selected': 0.021967212749921194},
#  {'pickup_latitude': 40.745642,
#   'pickup_longitude': -73.990757,
#   'trip_distance': 0.61,
#   'distance_from_selected': 0.017948053738502813},
#  {'pickup_latitude': 40.7595,
#   'pickup_longitude': -73.96904,
#   'trip_distance': 0.62,
#   'distance_from_selected': 0.013896852161542803},
#  {'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'trip_distance': 0.63,
#   'distance_from_selected': 0.03981974708609009},
#  {'pickup_latitude': 40.748042,
#   'pickup_longitude': -73.880385,
#   'trip_distance': 0.63,
#   'distance_from_selected': 0.10328337159968708},
#  {'pickup_latitude': 40.747865,
#   'pickup_longitude': -73.99322,
#   'trip_distance': 0.63,
#   'distance_from_selected': 0.017352107220737965},
#  {'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'trip_distance': 0.64,
#   'distance_from_selected': 0.024387985751185014},
#  {'pickup_latitude': 40.742522,
#   'pickup_longitude': -73.993292,
#   'trip_distance': 0.64,
#   'distance_from_selected': 0.021888407159954416},
#  {'pickup_latitude': 40.761322,
#   'pickup_longitude': -73.975755,
#   'trip_distance': 0.65,
#   'distance_from_selected': 0.007015737238515562},
#  {'pickup_latitude': 40.75857,
#   'pickup_longitude': -73.992855,
#   'trip_distance': 0.65,
#   'distance_from_selected': 0.010572068151508972},
#  {'pickup_latitude': 40.775292,
#   'pickup_longitude': -73.982082,
#   'trip_distance': 0.66,
#   'distance_from_selected': 0.013598912015303971},
#  {'pickup_latitude': 40.734912,
#   'pickup_longitude': -73.99062,
#   'trip_distance': 0.67,
#   'distance_from_selected': 0.027926911823545668},
#  {'pickup_latitude': 40.80409,
#   'pickup_longitude': -73.966942,
#   'trip_distance': 0.68,
#   'distance_from_selected': 0.04523575492903805},
#  {'pickup_latitude': 40.767895,
#   'pickup_longitude': -73.981112,
#   'trip_distance': 0.69,
#   'distance_from_selected': 0.006400791279211959},
#  {'pickup_latitude': 40.721366,
#   'pickup_longitude': -74.008287,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.04774165963809419},
#  {'pickup_latitude': 40.793086,
#   'pickup_longitude': -73.952092,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.043874589456773846},
#  {'pickup_latitude': 40.794651,
#   'pickup_longitude': -73.972048,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.0346389437627654},
#  {'pickup_latitude': 40.743232,
#   'pickup_longitude': -73.983751,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.018504555249993542},
#  {'pickup_latitude': 40.78079,
#   'pickup_longitude': -73.946522,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.04095410900019556},
#  {'pickup_latitude': 40.768497,
#   'pickup_longitude': -73.899785,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.08325211104831405},
#  {'pickup_latitude': 40.736343,
#   'pickup_longitude': -73.99289,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.027314860222966877},
#  {'pickup_latitude': 40.801351,
#   'pickup_longitude': -73.961519,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.04497320271005646},
#  {'pickup_latitude': 40.732783,
#   'pickup_longitude': -73.985831,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.029089557748446605},
#  {'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.968202,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.014683412035349138},
#  {'pickup_latitude': 40.758769,
#   'pickup_longitude': -73.992404,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.010082470778529033},
#  {'pickup_latitude': 40.701535,
#   'pickup_longitude': -74.012503,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.06712433741944793},
#  {'pickup_latitude': 40.760963,
#   'pickup_longitude': -73.975273,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.007524172911355095},
#  {'pickup_latitude': 40.754554,
#   'pickup_longitude': -73.993513,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.012916475719014808},
#  {'pickup_latitude': 40.744275,
#   'pickup_longitude': -74.006706,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.02962077212024919},
#  {'pickup_latitude': 40.75681,
#   'pickup_longitude': -73.96498,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.01844284142967293},
#  {'pickup_latitude': 40.742145,
#   'pickup_longitude': -73.984962,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.019688525312983415},
#  {'pickup_latitude': 40.754549,
#   'pickup_longitude': -73.993151,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.012619540482918504},
#  {'pickup_latitude': 40.776247,
#   'pickup_longitude': -73.94696,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.03863889709864322},
#  {'pickup_latitude': 40.757283,
#   'pickup_longitude': -73.984915,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.0049236525060168375},
#  {'pickup_latitude': 40.751243,
#   'pickup_longitude': -73.993928,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.015306283448307086},
#  {'pickup_latitude': 40.742625,
#   'pickup_longitude': -73.995955,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.02320226820808797},
#  {'pickup_latitude': 40.739342,
#   'pickup_longitude': -74.001677,
#   'trip_distance': 0.7,
#   'distance_from_selected': 0.029294714762224214},
#  {'pickup_latitude': 40.750685,
#   'pickup_longitude': -74.002108,
#   'trip_distance': 0.71,
#   'distance_from_selected': 0.02226871637522886},
#  {'pickup_latitude': 40.76705,
#   'pickup_longitude': -73.979222,
#   'trip_distance': 0.72,
#   'distance_from_selected': 0.006405704020637267},
#  {'pickup_latitude': 40.758372,
#   'pickup_longitude': -73.963047,
#   'trip_distance': 0.72,
#   'distance_from_selected': 0.019993614305568497},
#  {'pickup_latitude': 40.742227,
#   'pickup_longitude': -73.982747,
#   'trip_distance': 0.72,
#   'distance_from_selected': 0.01948300433711495},
#  {'pickup_latitude': 40.75708,
#   'pickup_longitude': -73.96923,
#   'trip_distance': 0.72,
#   'distance_from_selected': 0.014300272724674453},
#  {'pickup_latitude': 40.760887,
#   'pickup_longitude': -73.98696,
#   'trip_distance': 0.73,
#   'distance_from_selected': 0.004279874881346892},
#  {'pickup_latitude': 40.743565,
#   'pickup_longitude': -73.988827,
#   'trip_distance': 0.73,
#   'distance_from_selected': 0.01913242049506981},
#  {'pickup_latitude': 40.797632,
#   'pickup_longitude': -73.969822,
#   'trip_distance': 0.73,
#   'distance_from_selected': 0.038180910518217},
#  {'pickup_latitude': 40.72269,
#   'pickup_longitude': -73.9992,
#   'trip_distance': 0.73,
#   'distance_from_selected': 0.042341870530246434},
#  {'pickup_latitude': 40.713638,
#   'pickup_longitude': -74.011587,
#   'trip_distance': 0.74,
#   'distance_from_selected': 0.056052770787893884},
#  {'pickup_latitude': 40.736907,
#   'pickup_longitude': -73.98862,
#   'trip_distance': 0.74,
#   'distance_from_selected': 0.02548584722939206},
#  {'pickup_latitude': 40.753015,
#   'pickup_longitude': -73.985247,
#   'trip_distance': 0.74,
#   'distance_from_selected': 0.009043682546400159},
#  {'pickup_latitude': 40.7464,
#   'pickup_longitude': -73.97771,
#   'trip_distance': 0.74,
#   'distance_from_selected': 0.01612137090944673},
#  {'pickup_latitude': 40.776252,
#   'pickup_longitude': -73.958072,
#   'trip_distance': 0.74,
#   'distance_from_selected': 0.02865252358867966},
#  {'pickup_latitude': 40.749207,
#   'pickup_longitude': -74.003233,
#   'trip_distance': 0.75,
#   'distance_from_selected': 0.023988929488409357},
#  {'pickup_latitude': 40.759305,
#   'pickup_longitude': -73.986923,
#   'trip_distance': 0.75,
#   'distance_from_selected': 0.004807763929318955},
#  {'pickup_latitude': 40.753485,
#   'pickup_longitude': -73.97311,
#   'trip_distance': 0.76,
#   'distance_from_selected': 0.012679634261283898},
#  {'pickup_latitude': 40.794572,
#   'pickup_longitude': -73.97205,
#   'trip_distance': 0.76,
#   'distance_from_selected': 0.034563205059718716},
#  {'pickup_latitude': 40.739812,
#   'pickup_longitude': -74.00549,
#   'trip_distance': 0.76,
#   'distance_from_selected': 0.031562244913817726},
#  {'pickup_latitude': 40.782367,
#   'pickup_longitude': -73.97884,
#   'trip_distance': 0.77,
#   'distance_from_selected': 0.021025652165865095},
#  {'pickup_latitude': 40.757605,
#   'pickup_longitude': -73.97543,
#   'trip_distance': 0.77,
#   'distance_from_selected': 0.008401185928186826},
#  {'pickup_latitude': 40.7655,
#   'pickup_longitude': -73.97585,
#   'trip_distance': 0.78,
#   'distance_from_selected': 0.00788112936069975},
#  {'pickup_latitude': 40.770492,
#   'pickup_longitude': -73.966807,
#   'trip_distance': 0.78,
#   'distance_from_selected': 0.018210484150615398},
#  {'pickup_latitude': 40.770965,
#   'pickup_longitude': -73.964002,
#   'trip_distance': 0.78,
#   'distance_from_selected': 0.020916921116649268},
#  {'pickup_latitude': 40.75224,
#   'pickup_longitude': -73.97835,
#   'trip_distance': 0.79,
#   'distance_from_selected': 0.01044648266163992},
#  {'pickup_latitude': 40.75262,
#   'pickup_longitude': -73.98631,
#   'trip_distance': 0.79,
#   'distance_from_selected': 0.009758616705252769},
#  {'pickup_latitude': 40.731176,
#   'pickup_longitude': -73.991572,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.03178012743838965},
#  {'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.02412625799828633},
#  {'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.985352,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.003222683509135103},
#  {'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.014011034080320282},
#  {'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.018524555433256127},
#  {'pickup_latitude': 40.771909,
#   'pickup_longitude': -73.959023,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.025835339556503984},
#  {'pickup_latitude': 40.72381,
#   'pickup_longitude': -73.992617,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.03916082799175691},
#  {'pickup_latitude': 40.767446,
#   'pickup_longitude': -73.984105,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.005891580517992472},
#  {'pickup_latitude': 40.735396,
#   'pickup_longitude': -73.993911,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.028579212672848787},
#  {'pickup_latitude': 40.745964,
#   'pickup_longitude': -73.991152,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.01784270663324406},
#  {'pickup_latitude': 40.760289,
#   'pickup_longitude': -73.931531,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.05124870419824488},
#  {'pickup_latitude': 40.778392,
#   'pickup_longitude': -73.985658,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.016931849515037418},
#  {'pickup_latitude': 40.769837,
#   'pickup_longitude': -73.982025,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.008160168748257448},
#  {'pickup_latitude': 40.750106,
#   'pickup_longitude': -73.991395,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.014464302299106278},
#  {'pickup_latitude': 40.729556,
#   'pickup_longitude': -73.99331,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.03384054101222075},
#  {'pickup_latitude': 40.71897,
#   'pickup_longitude': -73.997061,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.04506912691633002},
#  {'pickup_latitude': 40.768712,
#   'pickup_longitude': -73.963437,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.020552526195093353},
#  {'pickup_latitude': 40.758719,
#   'pickup_longitude': -74.000013,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.017510342372435008},
#  {'pickup_latitude': 40.747263,
#   'pickup_longitude': -73.974266,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.01675899295900859},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 0.8,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.783943,
#   'pickup_longitude': -73.977602,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.022823480299900372},
#  {'pickup_latitude': 40.80307,
#   'pickup_longitude': -73.967911,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.04394476534241284},
#  {'pickup_latitude': 40.774341,
#   'pickup_longitude': -73.963669,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.022891230679019662},
#  {'pickup_latitude': 40.705808,
#   'pickup_longitude': -74.006866,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.06087801606491887},
#  {'pickup_latitude': 40.773538,
#   'pickup_longitude': -73.98794,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.012912551413256259},
#  {'pickup_latitude': 40.741328,
#   'pickup_longitude': -73.989642,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.021512504456710203},
#  {'pickup_latitude': 40.767331,
#   'pickup_longitude': -73.962998,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.02054585809840948},
#  {'pickup_latitude': 40.756805,
#   'pickup_longitude': -73.990317,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.009009288207183325},
#  {'pickup_latitude': 40.813836,
#   'pickup_longitude': -73.936919,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.06941553973714921},
#  {'pickup_latitude': 40.764099,
#   'pickup_longitude': -73.973033,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.01001607957236593},
#  {'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'trip_distance': 0.8,
#   'distance_from_selected': 0.00080072217404248},
#  {'pickup_latitude': 40.73385,
#   'pickup_longitude': -74.0027,
#   'trip_distance': 0.81,
#   'distance_from_selected': 0.0342605195524008},
#  {'pickup_latitude': 40.744997,
#   'pickup_longitude': -73.981732,
#   'trip_distance': 0.81,
#   'distance_from_selected': 0.01674458578168198},
#  {'pickup_latitude': 40.735872,
#   'pickup_longitude': -74.006705,
#   'trip_distance': 0.81,
#   'distance_from_selected': 0.03522733695583447},
#  {'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'trip_distance': 0.83,
#   'distance_from_selected': 0.03194113827025913},
#  {'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'trip_distance': 0.84,
#   'distance_from_selected': 0.015026153466538811},
#  {'pickup_latitude': 40.77463,
#   'pickup_longitude': -73.96322,
#   'trip_distance': 0.84,
#   'distance_from_selected': 0.02342515741675436},
#  {'pickup_latitude': 40.761712,
#   'pickup_longitude': -73.972542,
#   'trip_distance': 0.85,
#   'distance_from_selected': 0.01021800019572775},
#  {'pickup_latitude': 40.749747,
#   'pickup_longitude': -73.991562,
#   'trip_distance': 0.86,
#   'distance_from_selected': 0.014852224513522758},
#  {'pickup_latitude': 40.739887,
#   'pickup_longitude': -74.004942,
#   'trip_distance': 0.87,
#   'distance_from_selected': 0.031117269369273646},
#  {'pickup_latitude': 40.764207,
#   'pickup_longitude': -73.9772,
#   'trip_distance': 0.87,
#   'distance_from_selected': 0.006094965873573102},
#  {'pickup_latitude': 40.772117,
#   'pickup_longitude': -73.982692,
#   'trip_distance': 0.87,
#   'distance_from_selected': 0.010407222155792335},
#  {'pickup_latitude': 40.717055,
#   'pickup_longitude': -73.991325,
#   'trip_distance': 0.88,
#   'distance_from_selected': 0.045468981184978906},
#  {'pickup_latitude': 40.748863,
#   'pickup_longitude': -73.992155,
#   'trip_distance': 0.88,
#   'distance_from_selected': 0.015915760553614065},
#  {'pickup_latitude': 40.751217,
#   'pickup_longitude': -73.970895,
#   'trip_distance': 0.88,
#   'distance_from_selected': 0.015839232115228523},
#  {'pickup_latitude': 40.737382,
#   'pickup_longitude': -73.997073,
#   'trip_distance': 0.88,
#   'distance_from_selected': 0.02822611473441287},
#  {'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'trip_distance': 0.88,
#   'distance_from_selected': 0.02429070805884447},
#  {'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.02062105053094975},
#  {'pickup_latitude': 40.760257,
#   'pickup_longitude': -73.976186,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.006732658093205155},
#  {'pickup_latitude': 40.720338,
#   'pickup_longitude': -73.993645,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.04277996737960721},
#  {'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.01792747860130132},
#  {'pickup_latitude': 40.740407,
#   'pickup_longitude': -73.987223,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.021765481340878873},
#  {'pickup_latitude': 40.762111,
#   'pickup_longitude': -73.968438,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.014327612676220423},
#  {'pickup_latitude': 40.744083,
#   'pickup_longitude': -73.985687,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.01786836472651894},
#  {'pickup_latitude': 40.756054,
#   'pickup_longitude': -74.005378,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.023314464608902376},
#  {'pickup_latitude': 40.789094,
#   'pickup_longitude': -73.975968,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.028213732826408162},
#  {'pickup_latitude': 40.741078,
#   'pickup_longitude': -73.9899,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.021832522163049782},
#  {'pickup_latitude': 40.774347,
#   'pickup_longitude': -73.963485,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.023048197196303452},
#  {'pickup_latitude': 40.71032,
#   'pickup_longitude': -74.009677,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.058012558890292346},
#  {'pickup_latitude': 40.820267,
#   'pickup_longitude': -73.955068,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.06477475675755294},
#  {'pickup_latitude': 40.755617,
#   'pickup_longitude': -73.962448,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.021206178179958915},
#  {'pickup_latitude': 40.780242,
#   'pickup_longitude': -73.959577,
#   'trip_distance': 0.9,
#   'distance_from_selected': 0.029679732360655783},
#  {'pickup_latitude': 40.744757,
#   'pickup_longitude': -73.984962,
#   'trip_distance': 0.92,
#   'distance_from_selected': 0.017095409120580194},
#  {'pickup_latitude': 40.77302,
#   'pickup_longitude': -73.982,
#   'trip_distance': 0.94,
#   'distance_from_selected': 0.01133550616426272},
#  {'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'trip_distance': 0.95,
#   'distance_from_selected': 0.03555435118237839},
#  {'pickup_latitude': 40.7439,
#   'pickup_longitude': -73.999577,
#   'trip_distance': 0.95,
#   'distance_from_selected': 0.024495052337161097},
#  {'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'trip_distance': 0.96,
#   'distance_from_selected': 0.024795241841938882},
#  {'pickup_latitude': 40.751127,
#   'pickup_longitude': -73.993905,
#   'trip_distance': 0.96,
#   'distance_from_selected': 0.015369154628673111},
#  {'pickup_latitude': 40.777707,
#   'pickup_longitude': -73.955068,
#   'trip_distance': 0.97,
#   'distance_from_selected': 0.03198047643485099},
#  {'pickup_latitude': 40.750027,
#   'pickup_longitude': -73.89876,
#   'trip_distance': 0.98,
#   'distance_from_selected': 0.08480856377159376},
#  {'pickup_latitude': 40.73672,
#   'pickup_longitude': -74.001152,
#   'trip_distance': 0.98,
#   'distance_from_selected': 0.03102846699404172},
#  {'pickup_latitude': 40.734982,
#   'pickup_longitude': -73.990523,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.027832537667267714},
#  {'pickup_latitude': 40.792594,
#   'pickup_longitude': -73.964102,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.03608243921910074},
#  {'pickup_latitude': 40.721587,
#   'pickup_longitude': -73.995427,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.04207502843730816},
#  {'pickup_latitude': 40.740991,
#   'pickup_longitude': -74.005581,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.030823286683939653},
#  {'pickup_latitude': 40.750094,
#   'pickup_longitude': -73.979116,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.012174160833504788},
#  {'pickup_latitude': 40.72257,
#   'pickup_longitude': -73.997073,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.04167495133770759},
#  {'pickup_latitude': 40.778415,
#   'pickup_longitude': -73.945392,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.040931949000751394},
#  {'pickup_latitude': 40.756412,
#   'pickup_longitude': -73.967363,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.016283009949018025},
#  {'pickup_latitude': 40.779383,
#   'pickup_longitude': -73.95955,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.029172573232410414},
#  {'pickup_latitude': 40.759193,
#   'pickup_longitude': -73.97723,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.00607586940280248},
#  {'pickup_latitude': 40.755756,
#   'pickup_longitude': -73.884413,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.09852706493649759},
#  {'pickup_latitude': 40.729574,
#   'pickup_longitude': -73.991874,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.033403405395259066},
#  {'pickup_latitude': 40.749577,
#   'pickup_longitude': -73.992082,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.015300633091474279},
#  {'pickup_latitude': 40.77277,
#   'pickup_longitude': -73.982488,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.011063344159882619},
#  {'pickup_latitude': 40.848462,
#   'pickup_longitude': -73.937645,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.09778176071742158},
#  {'pickup_latitude': 40.780847,
#   'pickup_longitude': -73.981522,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.01917700219012413},
#  {'pickup_latitude': 40.779378,
#   'pickup_longitude': -73.97747,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.018442947812105308},
#  {'pickup_latitude': 40.763434,
#   'pickup_longitude': -73.965213,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.017631488451056852},
#  {'pickup_latitude': 40.783417,
#   'pickup_longitude': -73.951313,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.03821135509243251},
#  {'pickup_latitude': 40.762465,
#   'pickup_longitude': -73.957122,
#   'trip_distance': 1.0,
#   'distance_from_selected': 0.025649114390170154},
#  {'pickup_latitude': 40.74969,
#   'pickup_longitude': -73.97751,
#   'trip_distance': 1.01,
#   'distance_from_selected': 0.013116512493800787},
#  {'pickup_latitude': 40.750555,
#   'pickup_longitude': -73.991287,
#   'trip_distance': 1.01,
#   'distance_from_selected': 0.01404078893795019},
#  {'pickup_latitude': 40.770602,
#   'pickup_longitude': -73.982262,
#   'trip_distance': 1.02,
#   'distance_from_selected': 0.008905934425983631},
#  {'pickup_latitude': 40.750417,
#   'pickup_longitude': -73.994658,
#   'trip_distance': 1.02,
#   'distance_from_selected': 0.01640409256862741},
#  {'pickup_latitude': 40.79712,
#   'pickup_longitude': -73.964465,
#   'trip_distance': 1.02,
#   'distance_from_selected': 0.03985693321117078},
#  {'pickup_latitude': 40.75899,
#   'pickup_longitude': -73.973248,
#   'trip_distance': 1.02,
#   'distance_from_selected': 0.009893257501957374},
#  {'pickup_latitude': 40.7513,
#   'pickup_longitude': -73.986852,
#   'trip_distance': 1.03,
#   'distance_from_selected': 0.011185372769827796},
#  {'pickup_latitude': 40.762752,
#   'pickup_longitude': -73.993035,
#   'trip_distance': 1.03,
#   'distance_from_selected': 0.01032770008279399},
#  {'pickup_latitude': 40.75619,
#   'pickup_longitude': -73.974282,
#   'trip_distance': 1.03,
#   'distance_from_selected': 0.01011666367929613},
#  {'pickup_latitude': 40.752327,
#   'pickup_longitude': -73.97917,
#   'trip_distance': 1.03,
#   'distance_from_selected': 0.010046332116748546},
#  {'pickup_latitude': 40.755507,
#   'pickup_longitude': -73.976157,
#   'trip_distance': 1.03,
#   'distance_from_selected': 0.0090596257097062},
#  {'pickup_latitude': 40.742422,
#   'pickup_longitude': -73.991082,
#   'trip_distance': 1.04,
#   'distance_from_selected': 0.021006728160287893},
#  {'pickup_latitude': 40.766245,
#   'pickup_longitude': -73.98354,
#   'trip_distance': 1.04,
#   'distance_from_selected': 0.004601589399325278},
#  {'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.018142433491678843},
#  {'pickup_latitude': 40.75331,
#   'pickup_longitude': -73.968992,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.016128168649911827},
#  {'pickup_latitude': 40.757465,
#   'pickup_longitude': -73.963752,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.019476244222127573},
#  {'pickup_latitude': 40.751085,
#   'pickup_longitude': -73.990382,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.013076142741646408},
#  {'pickup_latitude': 40.761082,
#   'pickup_longitude': -73.961535,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.02123428852116425},
#  {'pickup_latitude': 40.748542,
#   'pickup_longitude': -73.987952,
#   'trip_distance': 1.05,
#   'distance_from_selected': 0.014154613664812316},
#  {'pickup_latitude': 40.787612,
#   'pickup_longitude': -73.977033,
#   'trip_distance': 1.06,
#   'distance_from_selected': 0.026527573070298568},
#  {'pickup_latitude': 40.767875,
#   'pickup_longitude': -73.98311,
#   'trip_distance': 1.06,
#   'distance_from_selected': 0.006174927125071669},
#  {'pickup_latitude': 40.729872,
#   'pickup_longitude': -74.002195,
#   'trip_distance': 1.06,
#   'distance_from_selected': 0.037301172488275566},
#  {'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'trip_distance': 1.07,
#   'distance_from_selected': 0.012581141641357043},
#  {'pickup_latitude': 40.73824,
#   'pickup_longitude': -73.993005,
#   'trip_distance': 1.08,
#   'distance_from_selected': 0.02560861036839176},
#  {'pickup_latitude': 40.74933,
#   'pickup_longitude': -73.97076,
#   'trip_distance': 1.08,
#   'distance_from_selected': 0.017241357255158823},
#  {'pickup_latitude': 40.753807,
#   'pickup_longitude': -73.979327,
#   'trip_distance': 1.08,
#   'distance_from_selected': 0.008616431860114146},
#  {'pickup_latitude': 40.74976,
#   'pickup_longitude': -73.993847,
#   'trip_distance': 1.08,
#   'distance_from_selected': 0.016301045027851638},
#  {'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'trip_distance': 1.09,
#   'distance_from_selected': 0.06739690296296812},
#  {'pickup_latitude': 40.768967,
#   'pickup_longitude': -73.954822,
#   'trip_distance': 1.09,
#   'distance_from_selected': 0.02886513282492176},
#  {'pickup_latitude': 40.779557,
#   'pickup_longitude': -73.977187,
#   'trip_distance': 1.09,
#   'distance_from_selected': 0.018696891131946083},
#  {'pickup_latitude': 40.748567,
#   'pickup_longitude': -73.972642,
#   'trip_distance': 1.09,
#   'distance_from_selected': 0.016586511779156567},
#  {'pickup_latitude': 40.73706,
#   'pickup_longitude': -73.99012,
#   'trip_distance': 1.09,
#   'distance_from_selected': 0.025725320211809607},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 1.09,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.14392561865769007},
#  {'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.01274683776470984},
#  {'pickup_latitude': 40.764762,
#   'pickup_longitude': -73.991849,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.009587733048016864},
#  {'pickup_latitude': 40.7678,
#   'pickup_longitude': -73.961987,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.021647300732429257},
#  {'pickup_latitude': 40.747572,
#   'pickup_longitude': -73.974092,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.01658364459339614},
#  {'pickup_latitude': 40.751251,
#   'pickup_longitude': -73.975745,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.01259368516360012},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 1.1,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.740112,
#   'pickup_longitude': -73.994987,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.024818806034936122},
#  {'pickup_latitude': 40.76084,
#   'pickup_longitude': -73.971439,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.011354379815731497},
#  {'pickup_latitude': 40.751163,
#   'pickup_longitude': -73.994115,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.01549758800587796},
#  {'pickup_latitude': 40.752832,
#   'pickup_longitude': -73.979423,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.009484432139040431},
#  {'pickup_latitude': 40.766653,
#   'pickup_longitude': -73.957138,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.026094446401483496},
#  {'pickup_latitude': 40.759037,
#   'pickup_longitude': -73.968693,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.014318708670823922},
#  {'pickup_latitude': 40.758312,
#   'pickup_longitude': -73.97752,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.006245318566737394},
#  {'pickup_latitude': 40.740555,
#   'pickup_longitude': -73.994539,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.024213196112866014},
#  {'pickup_latitude': 40.75531,
#   'pickup_longitude': -73.979295,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.007277789843079408},
#  {'pickup_latitude': 40.746683,
#   'pickup_longitude': -73.979712,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.015333004695755454},
#  {'pickup_latitude': 40.744849,
#   'pickup_longitude': -73.991395,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.018943509336971438},
#  {'pickup_latitude': 40.763148,
#   'pickup_longitude': -73.979234,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.0038079548316591627},
#  {'pickup_latitude': 40.73668,
#   'pickup_longitude': -73.995368,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.02802610504511917},
#  {'pickup_latitude': 40.730313,
#   'pickup_longitude': -74.00019,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.03591067402597802},
#  {'pickup_latitude': 40.765015,
#   'pickup_longitude': -73.976836,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.006783568456196345},
#  {'pickup_latitude': 40.735046,
#   'pickup_longitude': -73.990119,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.027660870864821333},
#  {'pickup_latitude': 40.759067,
#   'pickup_longitude': -73.977369,
#   'trip_distance': 1.1,
#   'distance_from_selected': 0.006004026149179211},
#  {'pickup_latitude': 40.735497,
#   'pickup_longitude': -74.00601,
#   'trip_distance': 1.11,
#   'distance_from_selected': 0.035038320008244216},
#  {'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'trip_distance': 1.12,
#   'distance_from_selected': 0.0415927040957891},
#  {'pickup_latitude': 40.756082,
#   'pickup_longitude': -73.976395,
#   'trip_distance': 1.12,
#   'distance_from_selected': 0.008496329148523357},
#  {'pickup_latitude': 40.751325,
#   'pickup_longitude': -73.978132,
#   'trip_distance': 1.12,
#   'distance_from_selected': 0.011369547440419864},
#  {'pickup_latitude': 40.751555,
#   'pickup_longitude': -73.992905,
#   'trip_distance': 1.13,
#   'distance_from_selected': 0.014354269399723308},
#  {'pickup_latitude': 40.751947,
#   'pickup_longitude': -73.986142,
#   'trip_distance': 1.13,
#   'distance_from_selected': 0.010332187232140355},
#  {'pickup_latitude': 40.740012,
#   'pickup_longitude': -73.99121,
#   'trip_distance': 1.13,
#   'distance_from_selected': 0.0232853109062337},
#  {'pickup_latitude': 40.777652,
#   'pickup_longitude': -73.959298,
#   'trip_distance': 1.14,
#   'distance_from_selected': 0.028365697735113913},
#  {'pickup_latitude': 40.768512,
#   'pickup_longitude': -73.965495,
#   'trip_distance': 1.14,
#   'distance_from_selected': 0.018556600685465663},
#  {'pickup_latitude': 40.719997,
#   'pickup_longitude': -73.99825,
#   'trip_distance': 1.14,
#   'distance_from_selected': 0.044496229829055337},
#  {'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'trip_distance': 1.17,
#   'distance_from_selected': 0.03455556176652355},
#  {'pickup_latitude': 40.762317,
#   'pickup_longitude': -73.98593,
#   'trip_distance': 1.18,
#   'distance_from_selected': 0.0032275918267316837},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 1.18,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.777555,
#   'pickup_longitude': -73.961237,
#   'trip_distance': 1.18,
#   'distance_from_selected': 0.026726457939653087},
#  {'pickup_latitude': 40.717302,
#   'pickup_longitude': -73.994352,
#   'trip_distance': 1.18,
#   'distance_from_selected': 0.045896023008541224},
#  {'pickup_latitude': 40.745012,
#   'pickup_longitude': -73.978387,
#   'trip_distance': 1.18,
#   'distance_from_selected': 0.017261122008720813},
#  {'pickup_latitude': 40.77247,
#   'pickup_longitude': -73.982419,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.010765402036150517},
#  {'pickup_latitude': 40.771542,
#   'pickup_longitude': -73.959533,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.025222247183789577},
#  {'pickup_latitude': 40.740332,
#   'pickup_longitude': -73.986289,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.021667319285041724},
#  {'pickup_latitude': 40.733125,
#   'pickup_longitude': -73.987273,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.028939063461003802},
#  {'pickup_latitude': 40.774453,
#   'pickup_longitude': -73.872166,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.11132572427340508},
#  {'pickup_latitude': 40.769545,
#   'pickup_longitude': -73.960554,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.023547689079819915},
#  {'pickup_latitude': 40.734922,
#   'pickup_longitude': -73.990548,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.027897130461756427},
#  {'pickup_latitude': 40.729687,
#   'pickup_longitude': -73.998358,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.03561979973273377},
#  {'pickup_latitude': 40.748232,
#   'pickup_longitude': -73.988848,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.01478919294620382},
#  {'pickup_latitude': 40.743367,
#   'pickup_longitude': -73.98406,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.018389008918374538},
#  {'pickup_latitude': 40.755034,
#   'pickup_longitude': -73.974168,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.010880783060049698},
#  {'pickup_latitude': 40.788362,
#   'pickup_longitude': -73.978052,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.027064633158420316},
#  {'pickup_latitude': 40.774893,
#   'pickup_longitude': -73.988128,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.014234005514962806},
#  {'pickup_latitude': 40.76102,
#   'pickup_longitude': -73.967407,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.015368497291542198},
#  {'pickup_latitude': 40.774696,
#   'pickup_longitude': -73.982317,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.012993553978798499},
#  {'pickup_latitude': 40.763994,
#   'pickup_longitude': -73.973275,
#   'trip_distance': 1.2,
#   'distance_from_selected': 0.009756120181708657},
# ...
#   'pickup_longitude': -73.986173,
#   'trip_distance': 5.64,
#   'distance_from_selected': 0.007790415778373344},
#  {'pickup_latitude': 40.708292,
#   'pickup_longitude': -73.939932,
#   'trip_distance': 5.75,
#   'distance_from_selected': 0.06846692857139186},
#  {'pickup_latitude': 40.74892,
#   'pickup_longitude': -73.97797,
#   'trip_distance': 5.79,
#   'distance_from_selected': 0.013657532720080266},
#  {'pickup_latitude': 40.78579,
#   'pickup_longitude': -73.976302,
#   'trip_distance': 5.79,
#   'distance_from_selected': 0.024930947916191094},
#  {'pickup_latitude': 40.691887,
#   'pickup_longitude': -73.982322,
#   'trip_distance': 5.8,
#   'distance_from_selected': 0.06982437377449179},
#  {'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'trip_distance': 5.88,
#   'distance_from_selected': 0.03747708325096438},
#  {'pickup_latitude': 40.712003,
#   'pickup_longitude': -73.945566,
#   'trip_distance': 5.9,
#   'distance_from_selected': 0.06208203834443388},
#  {'pickup_latitude': 40.715387,
#   'pickup_longitude': -74.013518,
#   'trip_distance': 6.01,
#   'distance_from_selected': 0.05560463013994835},
#  {'pickup_latitude': 40.74957,
#   'pickup_longitude': -73.992772,
#   'trip_distance': 6.04,
#   'distance_from_selected': 0.015735937976495706},
#  {'pickup_latitude': 40.68703,
#   'pickup_longitude': -73.98489,
#   'trip_distance': 6.07,
#   'distance_from_selected': 0.0747103694275439},
#  {'pickup_latitude': 40.758985,
#   'pickup_longitude': -73.989435,
#   'trip_distance': 6.13,
#   'distance_from_selected': 0.007209802355127857},
#  {'pickup_latitude': 40.786305,
#   'pickup_longitude': -73.977741,
#   'trip_distance': 6.2,
#   'distance_from_selected': 0.025101880128786},
#  {'pickup_latitude': 40.752788,
#   'pickup_longitude': -73.975128,
#   'trip_distance': 6.2,
#   'distance_from_selected': 0.011740933012328486},
#  {'pickup_latitude': 40.795953,
#   'pickup_longitude': -73.970739,
#   'trip_distance': 6.4,
#   'distance_from_selected': 0.03629170001529084},
#  {'pickup_latitude': 40.763605,
#   'pickup_longitude': -73.98895,
#   'trip_distance': 6.5,
#   'distance_from_selected': 0.006473571270947465},
#  {'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'trip_distance': 6.52,
#   'distance_from_selected': 0.029291399147190526},
#  {'pickup_latitude': 40.768147,
#   'pickup_longitude': -73.968142,
#   'trip_distance': 6.52,
#   'distance_from_selected': 0.015972504280792638},
#  {'pickup_latitude': 40.774152,
#   'pickup_longitude': -73.873092,
#   'trip_distance': 6.54,
#   'distance_from_selected': 0.11037152525900794},
#  {'pickup_latitude': 40.801657,
#   'pickup_longitude': -73.934415,
#   'trip_distance': 6.58,
#   'distance_from_selected': 0.06271364950311542},
#  {'pickup_latitude': 40.75318,
#   'pickup_longitude': -73.973152,
#   'trip_distance': 6.6,
#   'distance_from_selected': 0.0128481346506023},
#  {'pickup_latitude': 40.756005,
#   'pickup_longitude': -73.973294,
#   'trip_distance': 6.7,
#   'distance_from_selected': 0.011052247780431396},
#  {'pickup_latitude': 40.744418,
#   'pickup_longitude': -73.983521,
#   'trip_distance': 6.8,
#   'distance_from_selected': 0.01730873724452232},
#  {'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'trip_distance': 6.8,
#   'distance_from_selected': 0.03711729971320723},
#  {'pickup_latitude': 40.755782,
#   'pickup_longitude': -73.983322,
#   'trip_distance': 6.89,
#   'distance_from_selected': 0.0059545804218240315},
#  {'pickup_latitude': 40.756312,
#   'pickup_longitude': -73.994315,
#   'trip_distance': 6.98,
#   'distance_from_selected': 0.012753682958268397},
#  {'pickup_latitude': 40.712612,
#   'pickup_longitude': -73.95882,
#   'trip_distance': 7.04,
#   'distance_from_selected': 0.05462359567073451},
#  {'pickup_latitude': 40.721519,
#   'pickup_longitude': -73.956165,
#   'trip_distance': 7.1,
#   'distance_from_selected': 0.04819346953685765},
#  {'pickup_latitude': 40.777867,
#   'pickup_longitude': -73.945725,
#   'trip_distance': 7.1,
#   'distance_from_selected': 0.04040593859818402},
#  {'pickup_latitude': 40.789342,
#   'pickup_longitude': -73.948455,
#   'trip_distance': 7.27,
#   'distance_from_selected': 0.04404952268753958},
#  {'pickup_latitude': 40.741824,
#   'pickup_longitude': -73.982933,
#   'trip_distance': 7.4,
#   'distance_from_selected': 0.019886752500093786},
#  {'pickup_latitude': 40.737997,
#   'pickup_longitude': -73.992069,
#   'trip_distance': 7.4,
#   'distance_from_selected': 0.02547476889002272},
#  {'pickup_latitude': 40.72245,
#   'pickup_longitude': -73.98729,
#   'trip_distance': 7.46,
#   'distance_from_selected': 0.03952048203147229},
#  {'pickup_latitude': 40.752342,
#   'pickup_longitude': -73.974746,
#   'trip_distance': 7.6,
#   'distance_from_selected': 0.012328163691324185},
#  {'pickup_latitude': 40.77408,
#   'pickup_longitude': -73.874527,
#   'trip_distance': 7.65,
#   'distance_from_selected': 0.1089375930934753},
#  {'pickup_latitude': 40.763642,
#   'pickup_longitude': -73.988995,
#   'trip_distance': 7.68,
#   'distance_from_selected': 0.006527468804983552},
#  {'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78,
#   'distance_from_selected': 0.23266957584523507},
#  {'pickup_latitude': 40.707517,
#   'pickup_longitude': -74.004445,
#   'trip_distance': 7.8,
#   'distance_from_selected': 0.05837054457515362},
#  {'pickup_latitude': 40.773952,
#   'pickup_longitude': -73.871235,
#   'trip_distance': 8.12,
#   'distance_from_selected': 0.11219488486112049},
#  {'pickup_latitude': 40.773009,
#   'pickup_longitude': -73.885269,
#   'trip_distance': 8.2,
#   'distance_from_selected': 0.09814358095158857},
#  {'pickup_latitude': 40.743475,
#   'pickup_longitude': -73.923155,
#   'trip_distance': 8.26,
#   'distance_from_selected': 0.06233194405760761},
#  {'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'trip_distance': 8.3,
#   'distance_from_selected': 0.0012508768924205918},
#  {'pickup_latitude': 40.735785,
#   'pickup_longitude': -74.006038,
#   'trip_distance': 8.3,
#   'distance_from_selected': 0.03484208531360125},
#  {'pickup_latitude': 40.77365,
#   'pickup_longitude': -73.870572,
#   'trip_distance': 8.3,
#   'distance_from_selected': 0.1128215889978545},
#  {'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'trip_distance': 8.4,
#   'distance_from_selected': 0.10886237627849703},
#  {'pickup_latitude': 40.696647,
#   'pickup_longitude': -73.99152,
#   'trip_distance': 8.44,
#   'distance_from_selected': 0.06565006907079526},
#  {'pickup_latitude': 40.782482,
#   'pickup_longitude': -73.957812,
#   'trip_distance': 8.47,
#   'distance_from_selected': 0.032463497778270616},
#  {'pickup_latitude': 40.771724,
#   'pickup_longitude': -73.981772,
#   'trip_distance': 8.6,
#   'distance_from_selected': 0.010062620930947803},
#  {'pickup_latitude': 40.749792,
#   'pickup_longitude': -74.00267,
#   'trip_distance': 8.7,
#   'distance_from_selected': 0.023204456985671303},
#  {'pickup_latitude': 40.773595,
#   'pickup_longitude': -73.870591,
#   'trip_distance': 8.7,
#   'distance_from_selected': 0.11279688730633809},
#  {'pickup_latitude': 40.773907,
#   'pickup_longitude': -73.871275,
#   'trip_distance': 8.73,
#   'distance_from_selected': 0.11215022083794762},
#  {'pickup_latitude': 40.803842,
#   'pickup_longitude': -73.966812,
#   'trip_distance': 8.74,
#   'distance_from_selected': 0.04504935213740612},
#  {'pickup_latitude': 40.711467,
#   'pickup_longitude': -73.945825,
#   'trip_distance': 8.8,
#   'distance_from_selected': 0.062358265482613945},
#  {'pickup_latitude': 40.774487,
#   'pickup_longitude': -73.872417,
#   'trip_distance': 8.86,
#   'distance_from_selected': 0.11108028348001306},
#  {'pickup_latitude': 40.767302,
#   'pickup_longitude': -73.9646,
#   'trip_distance': 8.9,
#   'distance_from_selected': 0.01900147531113848},
#  {'pickup_latitude': 40.759859,
#   'pickup_longitude': -73.973301,
#   'trip_distance': 9.0,
#   'distance_from_selected': 0.009638406611046597},
#  {'pickup_latitude': 40.71592,
#   'pickup_longitude': -74.015208,
#   'trip_distance': 9.1,
#   'distance_from_selected': 0.05612126873120824},
#  {'pickup_latitude': 40.77409,
#   'pickup_longitude': -73.87317,
#   'trip_distance': 9.21,
#   'distance_from_selected': 0.1102870459301517},
#  {'pickup_latitude': 40.76952,
#   'pickup_longitude': -73.99197,
#   'trip_distance': 9.21,
#   'distance_from_selected': 0.012075603504583648},
#  {'pickup_latitude': 40.771907,
#   'pickup_longitude': -73.95626,
#   'trip_distance': 9.22,
#   'distance_from_selected': 0.0283941685738443},
#  {'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'trip_distance': 9.25,
#   'distance_from_selected': 0.10887380930691412},
#  {'pickup_latitude': 40.736197,
#   'pickup_longitude': -73.981978,
#   'trip_distance': 9.28,
#   'distance_from_selected': 0.025524981743386004},
#  {'pickup_latitude': 40.77411,
#   'pickup_longitude': -73.874625,
#   'trip_distance': 9.37,
#   'distance_from_selected': 0.10884364117853151},
#  {'pickup_latitude': 40.718398,
#   'pickup_longitude': -73.994967,
#   'trip_distance': 9.4,
#   'distance_from_selected': 0.04499933547287237},
#  {'pickup_latitude': 40.77293,
#   'pickup_longitude': -73.88525,
#   'trip_distance': 9.41,
#   'distance_from_selected': 0.09815339270753705},
#  {'pickup_latitude': 40.773118,
#   'pickup_longitude': -73.885322,
#   'trip_distance': 9.55,
#   'distance_from_selected': 0.09810354890624132},
#  {'pickup_latitude': 40.771097,
#   'pickup_longitude': -73.865913,
#   'trip_distance': 9.61,
#   'distance_from_selected': 0.11722344977860982},
#  {'pickup_latitude': 40.756307,
#   'pickup_longitude': -73.991625,
#   'trip_distance': 9.64,
#   'distance_from_selected': 0.010381745229007245},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 9.7,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.794829,
#   'pickup_longitude': -73.971476,
#   'trip_distance': 9.8,
#   'distance_from_selected': 0.03498852407575984},
#  {'pickup_latitude': 40.756705,
#   'pickup_longitude': -73.97462,
#   'trip_distance': 9.84,
#   'distance_from_selected': 0.009555606992755546},
#  {'pickup_latitude': 40.773777,
#   'pickup_longitude': -73.870957,
#   'trip_distance': 10.33,
#   'distance_from_selected': 0.11245231566312396},
#  {'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'trip_distance': 10.4,
#   'distance_from_selected': 84.46872663501978},
#  {'pickup_latitude': 40.762081,
#   'pickup_longitude': -73.978908,
#   'trip_distance': 10.5,
#   'distance_from_selected': 0.003869824931435699},
#  {'pickup_latitude': 40.758277,
#   'pickup_longitude': -73.937715,
#   'trip_distance': 10.72,
#   'distance_from_selected': 0.0451756296469697},
#  {'pickup_latitude': 40.751872,
#   'pickup_longitude': -73.987503,
#   'trip_distance': 10.74,
#   'distance_from_selected': 0.01092164332873425},
#  {'pickup_latitude': 40.751953,
#   'pickup_longitude': -73.976404,
#   'trip_distance': 10.9,
#   'distance_from_selected': 0.011644646194709696},
#  {'pickup_latitude': 40.756066,
#   'pickup_longitude': -73.980939,
#   'trip_distance': 10.9,
#   'distance_from_selected': 0.005930495510496166},
#  {'pickup_latitude': 40.757541,
#   'pickup_longitude': -73.974641,
#   'trip_distance': 10.9,
#   'distance_from_selected': 0.009126813354061415},
#  {'pickup_latitude': 40.749935,
#   'pickup_longitude': -73.979155,
#   'trip_distance': 11.1,
#   'distance_from_selected': 0.01231448943318208},
#  {'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'trip_distance': 11.2,
#   'distance_from_selected': 0.12030891972335112},
#  {'pickup_latitude': 40.779416,
#   'pickup_longitude': -73.957448,
#   'trip_distance': 11.3,
#   'distance_from_selected': 0.030890124311822822},
#  {'pickup_latitude': 40.641375,
#   'pickup_longitude': -73.788935,
#   'trip_distance': 11.5,
#   'distance_from_selected': 0.22814171659300397},
#  {'pickup_latitude': 40.772652,
#   'pickup_longitude': -73.885138,
#   'trip_distance': 11.98,
#   'distance_from_selected': 0.09823330518719318},
#  {'pickup_latitude': 40.771472,
#   'pickup_longitude': -73.8755,
#   'trip_distance': 12.06,
#   'distance_from_selected': 0.10770331584496044},
#  {'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'trip_distance': 12.15,
#   'distance_from_selected': 0.12012364943674277},
#  {'pickup_latitude': 40.77012,
#   'pickup_longitude': -73.86361,
#   'trip_distance': 12.55,
#   'distance_from_selected': 0.11944643401961022},
#  {'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7,
#   'distance_from_selected': 0.23219407134980613},
#  {'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'trip_distance': 12.7,
#   'distance_from_selected': 0.02961840409272819},
#  {'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.980648,
#   'trip_distance': 12.7,
#   'distance_from_selected': 0.0024634057725016426},
#  {'pickup_latitude': 40.786657,
#   'pickup_longitude': -73.975743,
#   'trip_distance': 13.75,
#   'distance_from_selected': 0.025915074724953732},
#  {'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'trip_distance': 14.43,
#   'distance_from_selected': 0.05347955267202561},
#  {'pickup_latitude': 40.745205,
#   'pickup_longitude': -73.982578,
#   'trip_distance': 14.6,
#   'distance_from_selected': 0.016506003422999505},
#  {'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'trip_distance': 16.0,
#   'distance_from_selected': 0.01147588589172489},
#  {'pickup_latitude': 40.745874,
#   'pickup_longitude': -73.991095,
#   'trip_distance': 16.1,
#   'distance_from_selected': 0.01789556148881745},
#  {'pickup_latitude': 40.728808,
#   'pickup_longitude': -73.987538,
#   'trip_distance': 16.4,
#   'distance_from_selected': 0.03324711849168309},
#  {'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'trip_distance': 16.63,
#   'distance_from_selected': 0.23006636330632702},
#  {'pickup_latitude': 40.646587,
#   'pickup_longitude': -73.78582,
#   'trip_distance': 16.79,
#   'distance_from_selected': 0.22811985606036164},
#  {'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3,
#   'distance_from_selected': 0.22916331710158447},
#  {'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'trip_distance': 17.5,
#   'distance_from_selected': 0.23656667039124177},
#  {'pickup_latitude': 40.766367,
#   'pickup_longitude': -73.952442,
#   'trip_distance': 17.55,
#   'distance_from_selected': 0.03067358428680379},
#  {'pickup_latitude': 40.753827,
#   'pickup_longitude': -73.994472,
#   'trip_distance': 17.65,
#   'distance_from_selected': 0.014117812613859863},
#  {'pickup_latitude': 40.648605,
#   'pickup_longitude': -73.78482,
#   'trip_distance': 18.2,
#   'distance_from_selected': 0.22797584219605477},
#  {'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'trip_distance': 18.38,
#   'distance_from_selected': 0.2329595469174876},
#  {'pickup_latitude': 40.642527,
#   'pickup_longitude': -73.791427,
#   'trip_distance': 18.5,
#   'distance_from_selected': 0.2254171785334915},
#  {'pickup_latitude': 40.764282,
#   'pickup_longitude': -73.984948,
#   'trip_distance': 18.6,
#   'distance_from_selected': 0.0033767629469686478},
#  {'pickup_latitude': 40.643172,
#   'pickup_longitude': -73.789035,
#   'trip_distance': 19.03,
#   'distance_from_selected': 0.22711370075140874},
#  {'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'trip_distance': 19.05,
#   'distance_from_selected': 0.23669954416517222},
#  {'pickup_latitude': 40.790777,
#   'pickup_longitude': -73.973482,
#   'trip_distance': 19.6,
#   'distance_from_selected': 0.030511830049994897},
#  {'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'trip_distance': 20.5,
#   'distance_from_selected': 0.23640660754090667},
#  {'pickup_latitude': 40.76767,
#   'pickup_longitude': -73.96166,
#   'trip_distance': 21.24,
#   'distance_from_selected': 0.02192559235232185},
#  {'pickup_latitude': 40.64534,
#   'pickup_longitude': -73.77668,
#   'trip_distance': 21.44,
#   'distance_from_selected': 0.2366663121358864},
#  {'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'trip_distance': 22.8,
#   'distance_from_selected': 0.11234708983324602},
#  {'pickup_latitude': 40.644032,
#   'pickup_longitude': -73.790294,
#   'trip_distance': 23.7,
#   'distance_from_selected': 0.2255909413961429},
#  {'pickup_latitude': 40.642817,
#   'pickup_longitude': -73.788912,
#   'trip_distance': 24.55,
#   'distance_from_selected': 0.22740402932446255}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
